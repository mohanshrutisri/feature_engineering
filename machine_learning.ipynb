# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\sanid\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dict={
    "name":["John","Jane","Jack","Jill","Joe","Jenny"],
    "marks":[25,30,35,40,45,50],
    "hours":[2,3,4,5,6,7],
}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#     name  marks  hours
# 0   John     25      2
# 1   Jane     30      3
# 2   Jack     35      4
# 3   Jill     40      5
# 4    Joe     45      6
# 5  Jenny     50      7

# %%
df.head
# Out:
# <bound method NDFrame.head of     name  marks  hours
# 0   John     25      2
# 1   Jane     30      3
# 2   Jack     35      4
# 3   Jill     40      5
# 4    Joe     45      6
# 5  Jenny     50      7>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      str
#  1   marks   6 non-null      int64
#  2   hours   6 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 276.0 bytes

# %%
df.plot(kind='line',x='name',y='marks')
plt.scatter(df['hours'],df['marks'])
plt.xlabel('Hours')
plt.ylabel('Marks')
plt.title('Hours vs Marks')
# Out:
# Text(0.5, 1.0, 'Hours vs Marks')

# %%
#call linear regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)

# %%
y_pred=model.predict(x)

# %%
#y=mx+c

# %%
h=float (input("Enter the number of hours: "))
marks = m*h+c
if marks=>100:
    marks=100
    print("Marks obtained: 50")
else:
    print(f"Marks obtained: {marks}")
